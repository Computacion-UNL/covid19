# %%
import cv2
import os
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
import glob
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import plot_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import *
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from tensorflow.keras.callbacks import *

# %%
print(tf.test.is_gpu_available())
# Out:
# WARNING:tensorflow:From C:\Users\jr-98\AppData\Local\Temp/ipykernel_15748/1706362843.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
imagePaths = []
for dirname, _, filenames in os.walk(r'C:\Users\jr-98\Documents\DataCovid19imgX\TAWSIFUR_RAHMAN\COVID-19_Radiography_Dataset'):
    for filename in filenames:
        if (filename[-3:] == 'png'):
            imagePaths.append(os.path.join(dirname, filename))

# %%
imgSize = 224

# %%
X = []
Y = []
hmap = {'NORMAL': 'Normal', 'COVID': 'Covid-19'}
for imagePath in tqdm(imagePaths):
    label = imagePath.split(os.path.sep)[-2]
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (imgSize, imgSize))
    X.append(image)
    Y.append(hmap[label])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:01<00:00, 724.98it/s]

# %%
print('Covid-19:',Y.count('Covid-19'))
print('Normal:',Y.count('Normal'))
# Out:
# Covid-19: 500
# Normal: 500

# %%
le = LabelEncoder()
Y = le.fit_transform(Y)
Y = to_categorical(Y)

# %%
(trainX, testX, trainY, testY) = train_test_split(X, Y, test_size=0.20, stratify=Y, random_state=42)

# %%
print(len(trainY))
ntimes = 6
trainY = trainY.tolist()
for i in tqdm(range(len(trainX))):
    if (trainY[i][0] == 1):
        trainX += [trainX[i]]*ntimes
        trainY += [trainY[i]]*ntimes
        
trainY = np.array(trainY)
print(len(trainY))
# Out:
# 800
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 800/800 [00:00<?, ?it/s]
# 3200

# %%
trainX = np.array(trainX).astype('float16')/255
testX = np.array(testX).astype('float16')/255

# %%
trainAug = ImageDataGenerator(rotation_range=20, horizontal_flip = True,fill_mode="nearest")

# %%
best_val_acc = 0
best_train_acc = 0
def saveModel(epoch,logs):
    val_acc = logs['val_accuracy']
    train_acc = logs['accuracy']
    global best_val_acc
    global best_train_acc

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        model.save('modelVGG16to7k.h5')
        model.save_weights('modelVGG16to7kPesos.h5')
    elif val_acc == best_val_acc:
        if train_acc > best_train_acc:
            best_train_acc= train_acc
            model.save('modelVGG16to7k.h5')
            model.save_weights('modelVGG16to7kPesos.h5')

# %% [markdown]
# # MODEL

# %%
baseModel = VGG16(weights="imagenet", include_top=False, input_tensor=Input(shape=(imgSize, imgSize, 3)))
headModel = baseModel.output
headModel = Flatten(name="flatten")(headModel)
print(headModel)
headModel = Dense(64, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(2, activation="softmax")(headModel)
model = Model(inputs=baseModel.input, outputs=headModel)
for layer in baseModel.layers:
    layer.trainable = False
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 25088), dtype=tf.float32, name=None), name='flatten/Reshape:0', description="created by layer 'flatten'")

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                1605696
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 16,320,514
# Trainable params: 1,605,826
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
plot_model(model, "my_first_model.png")
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
print(pydotprint.version)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15748/383102950.py in <module>
# ----> 1 print(pydotprint)
#
# NameError: name 'pydotprint' is not defined

# %% [markdown]
# # Train model

# %%
INIT_LR = 3e-4
EPOCHS = 50
BS = 32

opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)

model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
H = model.fit(
trainAug.flow(trainX, trainY, batch_size=BS),
steps_per_epoch=len(trainX) // BS,
validation_data=(testX, testY),
validation_steps=len(testX) // BS,
callbacks= [LambdaCallback(on_epoch_end=saveModel),
  ],
epochs=EPOCHS)
# Out:
# Epoch 1/50
# 700/700 [==============================] - 167s 230ms/step - loss: 0.2513 - accuracy: 0.9067 - val_loss: 0.3237 - val_accuracy: 0.8529
# Epoch 2/50
# 700/700 [==============================] - 156s 223ms/step - loss: 0.1596 - accuracy: 0.9394 - val_loss: 0.3561 - val_accuracy: 0.8250
# Epoch 3/50
# 700/700 [==============================] - 154s 220ms/step - loss: 0.1423 - accuracy: 0.9473 - val_loss: 0.3457 - val_accuracy: 0.8286
# Epoch 4/50
# 700/700 [==============================] - 154s 220ms/step - loss: 0.1212 - accuracy: 0.9547 - val_loss: 0.2507 - val_accuracy: 0.8793
# Epoch 5/50
# 700/700 [==============================] - 154s 220ms/step - loss: 0.1166 - accuracy: 0.9571 - val_loss: 0.2185 - val_accuracy: 0.8907
# Epoch 6/50
# 700/700 [==============================] - 155s 222ms/step - loss: 0.1079 - accuracy: 0.9628 - val_loss: 0.2078 - val_accuracy: 0.9071
# Epoch 7/50
# 700/700 [==============================] - 155s 221ms/step - loss: 0.0984 - accuracy: 0.9652 - val_loss: 0.1905 - val_accuracy: 0.9221
# Epoch 8/50
# 700/700 [==============================] - 155s 221ms/step - loss: 0.0969 - accuracy: 0.9669 - val_loss: 0.1817 - val_accuracy: 0.9100
# Epoch 9/50
# 700/700 [==============================] - 259s 370ms/step - loss: 0.0956 - accuracy: 0.9670 - val_loss: 0.1933 - val_accuracy: 0.9343
# Epoch 10/50
# 700/700 [==============================] - 157s 224ms/step - loss: 0.0961 - accuracy: 0.9675 - val_loss: 0.1631 - val_accuracy: 0.9279
# Epoch 11/50
# 700/700 [==============================] - 155s 221ms/step - loss: 0.0932 - accuracy: 0.9668 - val_loss: 0.1709 - val_accuracy: 0.9264
# Epoch 12/50
# 700/700 [==============================] - 156s 222ms/step - loss: 0.0961 - accuracy: 0.9652 - val_loss: 0.1803 - val_accuracy: 0.9186
# Epoch 13/50
# 700/700 [==============================] - 156s 223ms/step - loss: 0.0837 - accuracy: 0.9705 - val_loss: 0.1741 - val_accuracy: 0.9343
# Epoch 14/50
# 700/700 [==============================] - 157s 225ms/step - loss: 0.0836 - accuracy: 0.9698 - val_loss: 0.2069 - val_accuracy: 0.9279
# Epoch 15/50
# 700/700 [==============================] - 156s 223ms/step - loss: 0.0827 - accuracy: 0.9702 - val_loss: 0.1670 - val_accuracy: 0.9364
# Epoch 16/50
# 700/700 [==============================] - 157s 224ms/step - loss: 0.0767 - accuracy: 0.9742 - val_loss: 0.1519 - val_accuracy: 0.9436
# Epoch 17/50
# 700/700 [==============================] - 157s 225ms/step - loss: 0.0718 - accuracy: 0.9772 - val_loss: 0.1760 - val_accuracy: 0.9400
# Epoch 18/50
# 700/700 [==============================] - 157s 225ms/step - loss: 0.0870 - accuracy: 0.9694 - val_loss: 0.1460 - val_accuracy: 0.9507
# Epoch 19/50
# 700/700 [==============================] - 158s 226ms/step - loss: 0.0792 - accuracy: 0.9730 - val_loss: 0.1513 - val_accuracy: 0.9457
# Epoch 20/50
# 700/700 [==============================] - 158s 225ms/step - loss: 0.0690 - accuracy: 0.9755 - val_loss: 0.1683 - val_accuracy: 0.9343
# Epoch 21/50
# 700/700 [==============================] - 641s 917ms/step - loss: 0.0718 - accuracy: 0.9750 - val_loss: 0.1276 - val_accuracy: 0.9586
# Epoch 22/50
# 700/700 [==============================] - 165s 235ms/step - loss: 0.0707 - accuracy: 0.9751 - val_loss: 0.1685 - val_accuracy: 0.9350
# Epoch 23/50
# 700/700 [==============================] - 161s 230ms/step - loss: 0.0748 - accuracy: 0.9734 - val_loss: 0.1355 - val_accuracy: 0.9571
# Epoch 24/50
# 700/700 [==============================] - 162s 231ms/step - loss: 0.0621 - accuracy: 0.9795 - val_loss: 0.1454 - val_accuracy: 0.9414
# Epoch 25/50
# 700/700 [==============================] - 162s 232ms/step - loss: 0.0647 - accuracy: 0.9777 - val_loss: 0.1514 - val_accuracy: 0.9521
# Epoch 26/50
# 700/700 [==============================] - 173s 247ms/step - loss: 0.0678 - accuracy: 0.9768 - val_loss: 0.2123 - val_accuracy: 0.9357
# Epoch 27/50
# 700/700 [==============================] - 171s 245ms/step - loss: 0.0642 - accuracy: 0.9776 - val_loss: 0.1316 - val_accuracy: 0.9550
# Epoch 28/50
# 700/700 [==============================] - 162s 232ms/step - loss: 0.0564 - accuracy: 0.9820 - val_loss: 0.1404 - val_accuracy: 0.9564
# Epoch 29/50
# 700/700 [==============================] - 159s 227ms/step - loss: 0.0584 - accuracy: 0.9785 - val_loss: 0.1407 - val_accuracy: 0.9529
# Epoch 30/50
# 700/700 [==============================] - 160s 228ms/step - loss: 0.0581 - accuracy: 0.9804 - val_loss: 0.2122 - val_accuracy: 0.9321
# Epoch 31/50
# 700/700 [==============================] - 161s 229ms/step - loss: 0.0606 - accuracy: 0.9787 - val_loss: 0.2733 - val_accuracy: 0.9186
# Epoch 32/50
# 700/700 [==============================] - 161s 230ms/step - loss: 0.0624 - accuracy: 0.9773 - val_loss: 0.1850 - val_accuracy: 0.9350
# Epoch 33/50
# 700/700 [==============================] - 160s 228ms/step - loss: 0.0572 - accuracy: 0.9808 - val_loss: 0.1291 - val_accuracy: 0.9571
# Epoch 34/50
# 700/700 [==============================] - 160s 229ms/step - loss: 0.0587 - accuracy: 0.9796 - val_loss: 0.1413 - val_accuracy: 0.9521
# Epoch 35/50
# 700/700 [==============================] - 160s 228ms/step - loss: 0.0651 - accuracy: 0.9764 - val_loss: 0.1542 - val_accuracy: 0.9564
# Epoch 36/50
# 700/700 [==============================] - 161s 230ms/step - loss: 0.0551 - accuracy: 0.9816 - val_loss: 0.1446 - val_accuracy: 0.9564
# Epoch 37/50
# 700/700 [==============================] - 160s 228ms/step - loss: 0.0557 - accuracy: 0.9796 - val_loss: 0.1584 - val_accuracy: 0.9529
# Epoch 38/50
# 700/700 [==============================] - 222s 317ms/step - loss: 0.0527 - accuracy: 0.9828 - val_loss: 0.1093 - val_accuracy: 0.9607
# Epoch 39/50
# 700/700 [==============================] - 162s 231ms/step - loss: 0.0531 - accuracy: 0.9816 - val_loss: 0.2338 - val_accuracy: 0.9371
# Epoch 40/50
# 700/700 [==============================] - 163s 232ms/step - loss: 0.0540 - accuracy: 0.9823 - val_loss: 0.2805 - val_accuracy: 0.9150
# Epoch 41/50
# 700/700 [==============================] - 163s 233ms/step - loss: 0.0570 - accuracy: 0.9800 - val_loss: 0.1130 - val_accuracy: 0.9629
# Epoch 42/50
# 700/700 [==============================] - 164s 234ms/step - loss: 0.0510 - accuracy: 0.9830 - val_loss: 0.1331 - val_accuracy: 0.9543
# Epoch 43/50
# 700/700 [==============================] - 164s 234ms/step - loss: 0.0460 - accuracy: 0.9851 - val_loss: 0.1118 - val_accuracy: 0.9636
# Epoch 44/50
# 700/700 [==============================] - 165s 235ms/step - loss: 0.0476 - accuracy: 0.9837 - val_loss: 0.1431 - val_accuracy: 0.9607
# Epoch 45/50
# 700/700 [==============================] - 165s 235ms/step - loss: 0.0486 - accuracy: 0.9837 - val_loss: 0.2378 - val_accuracy: 0.9314
# Epoch 46/50
# 700/700 [==============================] - 165s 235ms/step - loss: 0.0487 - accuracy: 0.9825 - val_loss: 0.1464 - val_accuracy: 0.9571
# Epoch 47/50
# 700/700 [==============================] - 166s 237ms/step - loss: 0.0502 - accuracy: 0.9835 - val_loss: 0.1319 - val_accuracy: 0.9564
# Epoch 48/50
# 700/700 [==============================] - 165s 236ms/step - loss: 0.0461 - accuracy: 0.9844 - val_loss: 0.2547 - val_accuracy: 0.9221
# Epoch 49/50
# 700/700 [==============================] - 165s 236ms/step - loss: 0.0511 - accuracy: 0.9816 - val_loss: 0.1445 - val_accuracy: 0.9579
# Epoch 50/50
# 700/700 [==============================] - 166s 237ms/step - loss: 0.0480 - accuracy: 0.9828 - val_loss: 0.0990 - val_accuracy: 0.9679

# %%
N = EPOCHS
plt.style.use("ggplot")

plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy on COVID-19 Dataset")
plt.xlabel("Epoch Number")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.figure(figsize=(20,20))

# %%
from sklearn.metrics import accuracy_score
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 10))
t = f.suptitle('Transfer Learning VGG16 Performance', fontsize=16,fontweight='bold')
f.subplots_adjust(top=0.9, wspace=0.1)

max_epoch = len(H.history['accuracy'])+1
epoch_list = list(range(1,max_epoch))
ax1.plot(epoch_list, H.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, H.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(1, max_epoch, 1))
ax1.set_ylabel('Accuracy Value',fontsize=14,fontweight='bold')
ax1.set_xlabel('Epoch',fontsize=14,fontweight='bold')
ax1.set_title('Accuracy', fontsize=14,fontweight='bold')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, H.history['loss'], label='Train Loss')
ax2.plot(epoch_list, H.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(1, max_epoch, 1))
ax2.set_ylabel('Loss Value',fontsize=14,fontweight='bold')
ax2.set_xlabel('Epoch',fontsize=14,fontweight='bold')
ax2.set_title('Loss',fontsize=14,fontweight='bold')
l2 = ax2.legend(loc="best")

# %% [markdown]
# # Load best model

# %%
model= load_model('modelVGG16to1k.h5')

# %% [markdown]
# #Result on Train
# predIdxs = model.predict(trainX, batch_size=BS)
# predIdxs = np.argmax(predIdxs, axis=1)
# print(classification_report(trainY.argmax(axis=1), predIdxs, target_names=le.classes_, digits=5))

# %% [markdown]
# # Result on test

# %%
predIdxs = model.predict(testX, batch_size=32)
predIdxs = np.argmax(predIdxs, axis=1)
print(classification_report(Y.argmax(axis=1), predIdxs, target_names=le.classes_, digits = 5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7676/888030123.py in <module>
#       1 predIdxs = model.predict(testX, batch_size=32)
#       2 predIdxs = np.argmax(predIdxs, axis=1)
# ----> 3 print(classification_report(Y.argmax(axis=1), predIdxs, target_names=le.classes_, digits = 5))
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\sklearn\metrics\_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    1968     """
#    1969
# -> 1970     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1971
#    1972     if labels is None:
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      81     y_pred : array or indicator matrix
#      82     """
# ---> 83     check_consistent_length(y_true, y_pred)
#      84     type_true = type_of_target(y_true)
#      85     type_pred = type_of_target(y_pred)
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     317     uniques = np.unique(lengths)
#     318     if len(uniques) > 1:
# --> 319         raise ValueError("Found input variables with inconsistent numbers of"
#     320                          " samples: %r" % [int(l) for l in lengths])
#     321
#
# ValueError: Found input variables with inconsistent numbers of samples: [1000, 200]

# %%
import seaborn as sns
import sklearn
print(sns.version)
plt.figure()

ax = plt.subplot()

ax.set_title('Confusion Matrix')
pred = model.predict(testX)
pred=np.argmax(pred,axis=1)
# pred = model.predict_classes(X_test)
Y_TEST = np.argmax(testY, axis =1)
cm = sklearn.metrics.confusion_matrix(Y_TEST,pred)
classes=['normal','covid19']
sns.heatmap(cm, annot=True,xticklabels=classes, yticklabels=classes,cmap='Blues')

plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19452/1514991001.py in <module>
#       1 import seaborn as sns
#       2 import sklearn
# ----> 3 print(sns.version)
#       4 plt.figure()
#       5
#
# AttributeError: module 'seaborn' has no attribute 'version'
